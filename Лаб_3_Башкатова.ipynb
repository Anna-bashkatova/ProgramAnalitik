# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna-bashkatova/ProgramAnalitik/blob/main/%D0%9B%D0%B0%D0%B1_3_%D0%91%D0%B0%D1%88%D0%BA%D0%B0%D1%82%D0%BE%D0%B2%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Вариант 11

# %% [markdown]
# # Задание 1

# %% [markdown]
# Напишите программу для численного вычисления определённого интеграла с помощью средств SciPy. Сравните результаты вычисления различными функциями интегрирования с точным решением.
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import integrate
from scipy.integrate import *
from numpy.lib.scimath import *
from scipy.integrate import simps
from scipy.integrate import quad
import math
from sympy import *
import sympy as sym

# %% [markdown]
# **Вариант решения №1**
#
# Аналитическое решение

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
res = log(abs(sqrt(2)/2))
a = -2
res = a*res
res.subs({x:1}).n()
# Out:
# 0.693147180559945

# %% [markdown]
# **Вариант решения №2**
#
# Решение модуль Scipy quad

# %%
def f(x):
  return np.tan(x/2)

r = quad(f, 0.0, (np.pi/2))
print(r)
# Out:
# (0.6931471805599454, 7.695479593116622e-15)

# %% [markdown]
# **Вариант решения №3**

# %%
x = Symbol('x')
expr=sym.integrate(sym.tan(x/2), (x, 0, sym.pi / 2))
expr.subs({x:1}).n()
# Out:
# 0.693147180559945

# %% [markdown]
# **Вариант решения №4**
#
# Решение модуль Scipy quad - lambda

# %%
res = quad(lambda x: np.tan(x/2), 0, np.pi/2)
res
# Out:
# (0.6931471805599454, 7.695479593116622e-15)

# %% [markdown]
# **Вариант решения №5**
#
# Метод Симпсона

# %%
def f1(x):
  return np.tan(x/2)

x=np.arange(0, np.pi/2, 0.00000001)

y1=f1(x)
I1=simps(y1,x)
print(I1)
# Out:
# 0.6931471737650494

# %% [markdown]
# **Вариант решения №6**
#
# Метод Трапеции

# %%
def f1(x):
  return np.tan(x/2)

x=np.arange(0,np.pi/2,0.0000001)

res=trapz(f1(x), x)
res
# Out:
# 0.6931471537650481

# %% [markdown]
# # Задание 2

# %% [markdown]
# Напишите программу для численного решения обыкновенного дифференциального уравнения с заданным начальным условием с помощью средств SciPy. Сравните результат вычисления  с точным решением. Нарисуйте графики точного и численного решений, а также относительной ошибки численного решения.
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from scipy import integrate
from scipy.integrate import odeint   
import matplotlib.pyplot as plt

# %%
def f(y,x):
  return 1/(np.cos(y)*((x)**2))
y0 = 1
x = np.linspace(1,2,10)
y = odeint(f, y0, x)

fig = plt.figure()
ax = fig.add_subplot(111) 

ax.set(title='Решение ОДУ 1-го порядка')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')

plt.plot(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
